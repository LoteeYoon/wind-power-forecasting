# %% [markdown]
# - Exp 1
#
# ```
# GRU
# cols_inp     = ['Wspd', 'Wdir', 'Pab1', 'Ndir', 'Prtv', target]
# cols_out     = ['Wspd', 'Wdir', 'Pab1', 'Ndir', 'Prtv', target]
# cols_out_raw = ['Wspd', 'Wdir', 'Pab1', 'Ndir', 'Prtv', target]
# ```
# ![download.png](attachment:download.png)
# ![download-2.png](attachment:download-2.png)
# ![download-3.png](attachment:download-3.png)
#
#
# - Exp 2
# ```
# cols_inp     = ['Wspd', 'Wdir', 'Pab1', 'Ndir', 'Prtv', target]
# cols_out     = [target]
# ```
#
# - Exp 3
# ```
# GRU
# cols_sel = ['Etmp', 'Itmp', 'Prtv',
#             'Wspd', 'Wspd_extreme', 'Wspd_comb',
#             'Wdir', 'Wdir_active', 'Wdir_extreme', 'Wdir_comb',
#             'Ndir', 'Ndir_cos', 'Ndir_sin', 'Ndir_extreme', 'Ndir_comb',
#             'Pab', 'Pab_extreme1', 'Pab_extreme2',
#             'Prtv_pos', 'Prtv_abs', 'Prtv_comb',
#             'Wdir_cos', 'Wdir_sin', 'Wspd_cos', 'Wspd_sin',
#             'RPM', 'Wspd_cube',
#             'Patan_abs']
# cols_sel += ['Day_cos', 'Day_sin', 'Year_cos', 'Year_sin']
# cols_sel += [target]
# cols_out  = [target]
# ```
# ![download-4.png](attachment:download-4.png)
# ![download-5.png](attachment:download-5.png)
# ![download-6.png](attachment:download-6.png)
#
# - Exp 4
# ```
# GRU
# cols_inp     = ['Wspd', 'Wdir', 'Pab1', 'Ndir', 'Prtv',
#                 'Wspd_extreme', 'Wdir_extreme', 'Ndir_extreme', 'Pab_extreme1', 'Pab_extreme2', 'Prtv_abs', 'RPM', 'Wspd_cube',
#                 target]
# cols_out     = [target]
# ```
# ![download-7.png](attachment:download-7.png)
# ![download-8.png](attachment:download-8.png)
# ![download-9.png](attachment:download-9.png)
#
# [train] mean(MAE, RMSE): 154.44
# [val] mean(MAE, RMSE): 396.92
#
#
# - Exp 5
# ```
# Transformer
# cols_inp     = ['Wspd', 'Wdir', 'Pab1', 'Ndir', 'Prtv',
#                 'Wspd_extreme', 'Wdir_extreme', 'Ndir_extreme', 'Pab_extreme1', 'Pab_extreme2', 'Prtv_abs', 'RPM', 'Wspd_cube',
#                 target]
# cols_out     = [target]
# ```
# ![download-10.png](attachment:download-10.png)
# ![download-11.png](attachment:download-11.png)
# ![download-12.png](attachment:download-12.png)
#
#
# - Exp 6
# ```
# Time Series Transformer
# cols_sel = ['Etmp', 'Itmp', 'Prtv',
#             'Wspd', 'Wspd_extreme', 'Wspd_comb',
#             'Wdir', 'Wdir_active', 'Wdir_extreme', 'Wdir_comb',
#             'Ndir', 'Ndir_cos', 'Ndir_sin', 'Ndir_extreme', 'Ndir_comb',
#             'Pab', 'Pab_extreme1', 'Pab_extreme2',
#             'Prtv_pos', 'Prtv_abs', 'Prtv_comb',
#             'Wdir_cos', 'Wdir_sin', 'Wspd_cos', 'Wspd_sin',
#             'RPM', 'Wspd_cube',
#             'Patan_abs']
# cols_sel += ['Day_cos', 'Day_sin', 'Year_cos', 'Year_sin']
# cols_sel += [target]
# cols_out     = [target]
# ```
# ![download-15.png](attachment:download-15.png)
# ![download-13.png](attachment:download-13.png)
# ![download-14.png](attachment:download-14.png)
